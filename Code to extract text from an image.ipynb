# %% [markdown]
# ## Displaying the Picture

# %%
## Dispaying the Picture
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = "ai.jpg"  # Replace with the path to your image
img = mpimg.imread(image_path)

plt.imshow(img)
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# ## Code to extract text from an image

# %%
# Code to extract text from an image
from PIL import Image
import pytesseract

# Load the image
image_path = 'ai.jpg'
image = Image.open(image_path)

# Extract text using pytesseract
text = pytesseract.image_to_string(image)

# Print the extracted text
print(text)
# Out:
# ARTIFICIAL |
#
# INTELLIGENC!

# %% [markdown]
# ## Displaying the Picture¶

# %%
## Dispaying the Picture
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = "ai img txt ex.jpg"  # Replace with the path to your image
img = mpimg.imread(image_path)

plt.imshow(img)
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# ## Code to extract text from an image

# %%
# Code to extract text from an image
from PIL import Image
import pytesseract

# Load the image
image_path = 'ai img txt ex.jpg'
image = Image.open(image_path)

# Extract text using pytesseract
text = pytesseract.image_to_string(image)

# Print the extracted text
print(text)
# Out:
# 2:40 PM | 0.0KB/s & BB Nl G82
#
# =  ChatGPT G :
#
# © Keeping up with updates in these rapidly
#
# evolving frameworks.
#
# Trending Python AI/ML Projects (2025)
#
# These projects align with current industry trends and
#
# will belpiuow prepara far Wiah= paula roles?
# Beginner Level
#
# 1. Sentiment Analysis
# © Analyze sentiments from customer reviews,
# tweets, or social media.
# © Tools: NLTK, SpaCy, or Hugging Face.
# 2. Image Classification
# © Build a mode) to classify objects le.g., cats vs.
# dogs).
#
# © Tools: TensorFlow/Keras, OpenCV.
#
# 3. Predictive Analytics
# © Predict housing , ies forecasts, or stock
#
# trends.
#
# + — Message & oO
