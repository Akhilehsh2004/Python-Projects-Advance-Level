# %% [markdown]
# ## Akhilesh Pant (AU FTCA: MCA)¶

# %% [markdown]
# ## Text To English Voice

# %%
from gtts import gTTS
from IPython.display import Audio

# Define the text and language
language = "en"
text = "Jai Hind,. How are you all"

# Convert text to speech
speech = gTTS(text=text, lang=language, slow=False, tld="com.au")

# Save the speech as an MP3 file
speech.save("textToSpeech.mp3")

# Play the audio in Jupyter Notebook
Audio("textToSpeech.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Text To Hindi Voice

# %%
from gtts import gTTS
from IPython.display import Audio

# Define the text and language
language = "hi"
text = "Keso Ho App Sabhi "

# Convert text to speech
speech = gTTS(text=text, lang=language, slow=False, tld="com.au")

# Save the speech as an MP3 file
speech.save("textToSpeech.mp3")

# Play the audio in Jupyter Notebook
Audio("textToSpeech.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Here is a list of language codes supported by the `gTTS` library:
#
# | **Language**        | **Code** |
# |----------------------|----------|
# | Afrikaans            | `af`     |
# | Arabic               | `ar`     |
# | Bengali              | `bn`     |
# | Bulgarian            | `bg`     |
# | Cantonese            | `zh-CN`  |
# | Catalan              | `ca`     |
# | Chinese (Mandarin)   | `zh`     |
# | Croatian             | `hr`     |
# | Czech                | `cs`     |
# | Danish               | `da`     |
# | Dutch                | `nl`     |
# | English              | `en`     |
# | Filipino             | `fil`    |
# | Finnish              | `fi`     |
# | French               | `fr`     |
# | German               | `de`     |
# | Greek                | `el`     |
# | Gujarati             | `gu`     |
# | Hindi                | `hi`     |
# | Hungarian            | `hu`     |
# | Indonesian           | `id`     |
# | Italian              | `it`     |
# | Japanese             | `ja`     |
# | Kannada              | `kn`     |
# | Korean               | `ko`     |
# | Latin                | `la`     |
# | Malayalam            | `ml`     |
# | Marathi              | `mr`     |
# | Nepali               | `ne`     |
# | Norwegian            | `no`     |
# | Polish               | `pl`     |
# | Portuguese           | `pt`     |
# | Punjabi              | `pa`     |
# | Romanian             | `ro`     |
# | Russian              | `ru`     |
# | Serbian              | `sr`     |
# | Sinhala              | `si`     |
# | Slovak               | `sk`     |
# | Spanish              | `es`     |
# | Swedish              | `sv`     |
# | Tamil                | `ta`     |
# | Telugu               | `te`     |
# | Thai                 | `th`     |
# | Turkish              | `tr`     |
# | Ukrainian            | `uk`     |
# | Urdu                 | `ur`     |
# | Vietnamese           | `vi`     |
# | Zulu                 | `zu`     |
#
# You can use these language codes in the `lang` parameter of `gTTS`. Let me know if you need any further assistance!
